# %% [markdown]
# <a href="https://colab.research.google.com/github/Bin7amood/Assignment-/blob/main/ASS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
traindata = pd.read_csv("/content/data_train.csv")
traindata.head()
# Out:
# <ipython-input-2-9f976d42ad50>:2: DtypeWarning: Columns (9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata = pd.read_csv("/content/data_train.csv")
#   manufacturer_name transmission  color  odometer_value  year_produced  \
# 0        Volkswagen    automatic  black          130000           2016
# 1           Renault       manual  brown          149000           2012
# 2               Kia    automatic  brown          110000           2014
# 3              Opel    automatic  other          255100           2007
# 4             Mazda       manual   blue          650000           1999
#
#   engine_fuel engine_type  engine_capacity  body_type has_warranty ownership  \
# 0      diesel      diesel              1.6  universal        False     owned
# 1    gasoline    gasoline              1.6      sedan        False     owned
# 2    gasoline    gasoline              1.6  hatchback        False     owned
# ...

# %%
traindata.shape
# Out:
# (42292, 17)

# %%
testdata = pd.read_csv("/content/data_test.csv")
testdata.head()
# Out:
#   manufacturer_name transmission   color  odometer_value  year_produced  \
# 0               BMW    automatic   white          115000           2012
# 1     Mercedes-Benz       manual   other          500000           1999
# 2              Fiat       manual  silver          210000           2002
# 3        Mitsubishi    automatic  violet          294000           2000
# 4              Opel    automatic    blue          244000           1998
#
#   engine_fuel engine_type  engine_capacity  body_type  has_warranty ownership  \
# 0    gasoline    gasoline              4.4      sedan         False     owned
# 1      diesel      diesel              2.2      sedan         False     owned
# 2    gasoline    gasoline              1.2  hatchback         False     owned
# 3      diesel      diesel              3.2        suv         False     owned
# 4    gasoline    gasoline              1.6      sedan         False     owned
#
# ...

# %%
testdata.shape
# Out:
# (27000, 17)

# %%
traindata.isnull().sum()
# Out:
# manufacturer_name         0
# transmission              0
# color                     0
# odometer_value            0
# year_produced             0
# engine_fuel               0
# engine_type               0
# engine_capacity          12
# body_type                 0
# has_warranty              0
# ownership                 1
# type_of_drive             1
# is_exchangeable           1
# number_of_photos          1
# number_of_maintenance     1
# duration_listed           1
# price_usd                 1
# dtype: int64

# %%
testdata.isnull().sum()
# Out:
# manufacturer_name        0
# transmission             0
# color                    0
# odometer_value           0
# year_produced            0
# engine_fuel              0
# engine_type              0
# engine_capacity          5
# body_type                0
# has_warranty             0
# ownership                0
# type_of_drive            0
# is_exchangeable          0
# number_of_photos         0
# number_of_maintenance    0
# duration_listed          0
# price_usd                0
# dtype: int64

# %%
traindata = traindata.dropna()
testdata = testdata.dropna()

# %%
traindata.isnull().sum()
# Out:
# manufacturer_name        0
# transmission             0
# color                    0
# odometer_value           0
# year_produced            0
# engine_fuel              0
# engine_type              0
# engine_capacity          0
# body_type                0
# has_warranty             0
# ownership                0
# type_of_drive            0
# is_exchangeable          0
# number_of_photos         0
# number_of_maintenance    0
# duration_listed          0
# price_usd                0
# dtype: int64

# %%
testdata.isnull().sum()
# Out:
# manufacturer_name        0
# transmission             0
# color                    0
# odometer_value           0
# year_produced            0
# engine_fuel              0
# engine_type              0
# engine_capacity          0
# body_type                0
# has_warranty             0
# ownership                0
# type_of_drive            0
# is_exchangeable          0
# number_of_photos         0
# number_of_maintenance    0
# duration_listed          0
# price_usd                0
# dtype: int64

# %%
traindata.shape
# Out:
# (42279, 17)

# %%
testdata.shape
# Out:
# (26995, 17)

# %%
traindata.dtypes
# Out:
# manufacturer_name         object
# transmission              object
# color                     object
# odometer_value             int64
# year_produced              int64
# engine_fuel               object
# engine_type               object
# engine_capacity          float64
# body_type                 object
# has_warranty              object
# ownership                 object
# type_of_drive             object
# is_exchangeable           object
# number_of_photos         float64
# number_of_maintenance    float64
# duration_listed          float64
# price_usd                float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
corr = traindata.corr()

sns.heatmap(corr,annot=True)
plt.show()
# Out:
# <ipython-input-14-3da4259d4b4d>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = traindata.corr()

# %%
traindata.describe()
# Out:
#        odometer_value  year_produced  engine_capacity  number_of_photos  \
# count    42279.000000   42279.000000     42279.000000      42279.000000
# mean    249325.257598    2002.911942         2.055445          9.620379
# std     136070.206228       8.073869         0.672324          6.128022
# min          0.000000    1942.000000         0.200000          1.000000
# 25%     159000.000000    1997.000000         1.600000          5.000000
# 50%     250000.000000    2003.000000         2.000000          8.000000
# 75%     325000.000000    2009.000000         2.300000         12.000000
# max    1000000.000000    2019.000000         8.000000         86.000000
#
#        number_of_maintenance  duration_listed     price_usd
# count           42279.000000     42279.000000  42279.000000
# mean               16.175998        80.818279   6625.772378
# std                41.136074       113.406239   6441.613243
# min                 1.000000         0.000000      1.000000
# ...

# %%
testdata.describe()
# Out:
#        odometer_value  year_produced  engine_capacity  number_of_photos  \
# count    26995.000000   26995.000000     26995.000000      26995.000000
# mean    248253.283497    2002.935655         2.052027          9.623597
# std     135573.549451       8.063814         0.663980          5.997012
# min          0.000000    1942.000000         0.200000          1.000000
# 25%     157000.000000    1998.000000         1.600000          5.000000
# 50%     249000.000000    2003.000000         2.000000          8.000000
# 75%     324000.000000    2009.000000         2.300000         12.000000
# max    1000000.000000    2019.000000         8.000000         71.000000
#
#        number_of_maintenance  duration_listed     price_usd
# count           26995.000000     26995.000000  26995.000000
# mean               16.387776        80.270828   6610.308694
# std                46.373189       111.433261   6357.865198
# min                 1.000000         0.000000      1.000000
# ...

# %%
import matplotlib.pyplot as plt

traindata['price_usd'].plot(kind = 'hist', bins = 5, edgeclor = 'black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distrbution of Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ac58a67bcaac> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 traindata['price_usd'].plot(kind = 'hist', bins = 5, edgeclor = 'black')
#       4 plt.xlabel('Price')
#       5 plt.ylabel('Frequency')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
# ...

# %%
traindata.describe() #object
# Out:
#        odometer_value  year_produced  engine_capacity  number_of_photos  \
# count    42279.000000   42279.000000     42279.000000      42279.000000
# mean    249325.257598    2002.911942         2.055445          9.620379
# std     136070.206228       8.073869         0.672324          6.128022
# min          0.000000    1942.000000         0.200000          1.000000
# 25%     159000.000000    1997.000000         1.600000          5.000000
# 50%     250000.000000    2003.000000         2.000000          8.000000
# 75%     325000.000000    2009.000000         2.300000         12.000000
# max    1000000.000000    2019.000000         8.000000         86.000000
#
#        number_of_maintenance  duration_listed     price_usd
# count           42279.000000     42279.000000  42279.000000
# mean               16.175998        80.818279   6625.772378
# std                41.136074       113.406239   6441.613243
# min                 1.000000         0.000000      1.000000
# ...

# %%
import seaborn as sns
plt.figure(figsize = (10,6))
sns.regplot(x = "odometer_value", y = "price_usd", data=traindata)
# as observed in the plot, a negative correlation is obesrved
# Out:
# <Axes: xlabel='odometer_value', ylabel='price_usd'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(traindata['odometer_value'], traindata['price_usd'])
print("The Pearson Correlation Coefficient is ",pearson_coef, " with a p-value of p =", p_value)
# Out:
# The Pearson Correlation Coefficient is  -0.4220856072600057  with a p-value of p = 0.0
